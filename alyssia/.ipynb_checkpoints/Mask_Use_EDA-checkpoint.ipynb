# %% [markdown]
# # Exploratory Data Analysis - read dataframes

# %%
# imports

import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.dates as mdates

# %matplotlib inline

# %%
# read the CSV files

df = pd.read_csv('../clean_data/cases_with_mask_use.csv')

# %% [markdown]
# ## mask.csv basic inspection

# %%
# check the size of dataframes  
df.shape
# Out:
# (17486, 12)

# %%
# check how many null values are in each

df.isnull().sum()
# Out:
# county                 0
# totalcountconfirmed    0
# totalcountdeaths       0
# newcountconfirmed      0
# newcountdeaths         0
# date                   0
# NEVER                  0
# RARELY                 0
# SOMETIMES              0
# FREQUENTLY             0
# ALWAYS                 0
# population             0
# dtype: int64

# %%
# check whether all the columns are in the dtype we want

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17486 entries, 0 to 17485
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   county               17486 non-null  object
#  1   totalcountconfirmed  17486 non-null  float64
#  2   totalcountdeaths     17486 non-null  float64
#  3   newcountconfirmed    17486 non-null  int64
#  4   newcountdeaths       17486 non-null  int64
#  5   date                 17486 non-null  object
#  6   NEVER                17486 non-null  float64
#  7   RARELY               17486 non-null  float64
#  8   SOMETIMES            17486 non-null  float64
#  9   FREQUENTLY           17486 non-null  float64
#  10  ALWAYS               17486 non-null  float64
#  11  population           17486 non-null  int64
# dtypes: float64(7), int64(3), object(2)
# memory usage: 1.6+ MB

# %%
# check how many counties we have

df.nunique()
# Out:
# county                   58
# totalcountconfirmed    7956
# totalcountdeaths       1269
# newcountconfirmed      1313
# newcountdeaths          108
# date                    302
# NEVER                    37
# RARELY                   38
# SOMETIMES                46
# FREQUENTLY               45
# ALWAYS                   54
# population               58
# dtype: int64

# %%
df.describe()
# Out:
#        totalcountconfirmed  totalcountdeaths  newcountconfirmed  \
# count         17486.000000      17486.000000       17486.000000
# mean          11864.667048        196.650292         161.083438
# std           45130.684475        784.510735         777.737090
# min               0.000000          0.000000        -578.000000
# 25%              83.000000          1.000000           1.000000
# 50%             930.000000         13.000000          13.000000
# 75%            7530.000000        105.000000          81.000000
# max          937985.000000      12955.000000       28549.000000
#
#        newcountdeaths         NEVER        RARELY     SOMETIMES    FREQUENTLY  \
# count    17486.000000  17486.000000  17486.000000  17486.000000  17486.000000
# mean         1.810248      0.032278      0.030698      0.063649      0.158543
# std          9.369938      0.028532      0.026178      0.033899      0.040410
# min        -16.000000      0.001000      0.000000      0.004000      0.058000
# 25%          0.000000      0.015000      0.013000      0.040000      0.134000
# 50%          0.000000      0.023000      0.023000      0.058000      0.156000
# 75%          0.000000      0.043000      0.043000      0.084000      0.186000
# max        318.000000      0.140000      0.135000      0.162000      0.276000
#
#              ALWAYS    population
# count  17486.000000  1.748600e+04
# mean       0.714797  6.824013e+05
# std        0.092762  1.456244e+06
# min        0.482000  1.129000e+03
# 25%        0.661000  4.590500e+04
# 50%        0.737000  1.928430e+05
# 75%        0.786000  7.621480e+05
# max        0.889000  1.003911e+07

# %%
df.columns
# Out:
# Index(['county', 'totalcountconfirmed', 'totalcountdeaths',
#        'newcountconfirmed', 'newcountdeaths', 'date', 'NEVER', 'RARELY',
#        'SOMETIMES', 'FREQUENTLY', 'ALWAYS', 'population'],
#       dtype='object')

# %%
# fix dtype of date

df['date'] = pd.to_datetime(df['date'])

# %%
# sort the dataframe by name of counties & date
# check the top 5 lines 
df = df.sort_values(['county', 'date'])
df.head().tail()
# Out:
#         county  totalcountconfirmed  totalcountdeaths  newcountconfirmed  \
# 10238  Alameda                 29.0               0.0                 29
# 10239  Alameda                 36.0               0.0                  7
# 10240  Alameda                 42.0               0.0                  6
# 10241  Alameda                 62.0               0.0                 20
# 10242  Alameda                 72.0               1.0                 10
#
#        newcountdeaths       date  NEVER  RARELY  SOMETIMES  FREQUENTLY  \
# 10238               0 2020-03-18  0.019   0.008      0.055       0.123
# 10239               0 2020-03-19  0.019   0.008      0.055       0.123
# 10240               0 2020-03-20  0.019   0.008      0.055       0.123
# 10241               0 2020-03-21  0.019   0.008      0.055       0.123
# 10242               1 2020-03-22  0.019   0.008      0.055       0.123
#
#        ALWAYS  population  confirmedper100k  newlyconfirmedper100k  \
# 10238   0.795     1671329          1.735146               1.735146
# 10239   0.795     1671329          2.153974               0.418828
# 10240   0.795     1671329          2.512970               0.358996
# 10241   0.795     1671329          3.709623               1.196652
# 10242   0.795     1671329          4.307949               0.598326
#
#        deathper100k  newdeath100k  7dayrollingavg_newlyconfirmed  \
# 10238      0.000000      0.000000                            NaN
# 10239      0.000000      0.000000                            NaN
# 10240      0.000000      0.000000                            NaN
# 10241      0.000000      0.000000                            NaN
# 10242      0.059833      0.059833                            NaN
#
#        7dayrollingavg_newdeath  7dayrollingavg_newlyconfirmed_rawnumber  \
# 10238                      NaN                                      NaN
# 10239                      NaN                                      NaN
# 10240                      NaN                                      NaN
# 10241                      NaN                                      NaN
# 10242                      NaN                                      NaN
#
#        7dayrollingavg_newdeath_rawnumber
# 10238                                NaN
# 10239                                NaN
# 10240                                NaN
# 10241                                NaN
# 10242                                NaN

# %%
# make new columns normalized to population
# popular metrics used lists numbers per 100K population, so follow the same method

df['confirmedper100k'] = df['totalcountconfirmed']/df['population']*100000
df['newlyconfirmedper100k'] = df['newcountconfirmed']/df['population']*100000
df['deathper100k'] = df['totalcountdeaths']/df['population']*100000
df['newdeath100k'] = df['newcountdeaths']/df['population']*100000


df.index
# Out:
# Int64Index([10238, 10239, 10240, 10241, 10242, 10243, 10244, 10245, 10246,
#             10247,
#             ...
#              3009,  3010,  3011,  3012,  3013,  3014,  3015,  3016,  3017,
#              3018],
#            dtype='int64', length=17486)

# %%
# daily cases fluctuate a lot
# added 7-day rolling average columns to smooth out the variations 

df_bycounty = pd.DataFrame(df.groupby('county', sort=False)['newlyconfirmedper100k'].rolling(7).mean())
df_bycounty.set_index(keys=df.index, inplace=True)
df_bycounty.tail(30)
df_bycounty.columns = ['7dayrollingavg_newlyconfirmed']

merged = pd.merge(df, df_bycounty, left_index=True, right_index=True)

# %%
# repeat for daily deaths count
# pd. merge used to avoid conflict with groupby().rolling function 


df_bycounty2 = pd.DataFrame(df.groupby('county', sort=False)['newdeath100k'].rolling(7).mean())
df_bycounty2.set_index(keys=df.index, inplace=True)

df_bycounty2.columns = ['7dayrollingavg_newdeath']

merged2 = pd.merge(merged, df_bycounty2, left_index=True, right_index=True)


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17486 entries, 10238 to 3018
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   county                         17486 non-null  object
#  1   totalcountconfirmed            17486 non-null  float64
#  2   totalcountdeaths               17486 non-null  float64
#  3   newcountconfirmed              17486 non-null  int64
#  4   newcountdeaths                 17486 non-null  int64
#  5   date                           17486 non-null  datetime64[ns]
#  6   NEVER                          17486 non-null  float64
#  7   RARELY                         17486 non-null  float64
#  8   SOMETIMES                      17486 non-null  float64
#  9   FREQUENTLY                     17486 non-null  float64
#  10  ALWAYS                         17486 non-null  float64
#  11  population                     17486 non-null  int64
#  12  confirmedper100k               17486 non-null  float64
#  13  newlyconfirmedper100k          17486 non-null  float64
#  14  deathper100k                   17486 non-null  float64
#  15  newdeath100k                   17486 non-null  float64
#  16  7dayrollingavg_newlyconfirmed  17138 non-null  float64
#  17  7dayrollingavg_newdeath        17138 non-null  float64
# dtypes: datetime64[ns](1), float64(13), int64(3), object(1)
# memory usage: 3.2+ MB

# %%
# graph the daily confirmed normalized by 100k population 
# light blue dots = normalized daily count
# dark blue line = 7-day rolling average


sns.set_theme(style="darkgrid")

g = sns.FacetGrid(df, col="county", col_wrap=4, height=4, aspect=1, sharex=False, margin_titles=True, ylim=(0,500))
g.map(sns.lineplot, "date", '7dayrollingavg_newlyconfirmed', label='7-Day Average')
g.map(sns.scatterplot, "date", 'newlyconfirmedper100k', alpha=.5, color='lightskyblue', label='DailyConfirmed per 100K')

xformatter = mdates.DateFormatter("%y/%m")

g.axes[0].xaxis.set_major_formatter(xformatter)

g.set_xticklabels(rotation=50)
g.fig.tight_layout()
g.add_legend()

# %%
# graph the daily deaths normalized by 100k population 
# light pink dots = normalized daily deaths
# dark red line = 7-day rolling average

g = sns.FacetGrid(df, col="county", col_wrap=4, height=4, aspect=1, sharex=False, margin_titles=True, ylim=(0,10))
g.map(sns.lineplot, "date", '7dayrollingavg_newdeath', color='crimson', label='7-Day Average')
g.map(sns.scatterplot, "date", 'newdeath100k', alpha=.5, color='lightpink', label='DailyDeath per 100K')

xformatter = mdates.DateFormatter("%y/%m")

g.axes[0].xaxis.set_major_formatter(xformatter)

g.set_xticklabels(rotation=50)
g.fig.tight_layout()

g.add_legend()

# %% [markdown]
# - however, normalized graphs can exaggerate the fluctuations where the population is low
# - ex) 1 confirmed out of 10 population = 10% increase
# - in order to decide what constitutes as an "outbreak," let's look at the raw numbers before normalization

# %%
# repeat the same process of generating a new column of rolling average
# but this time, use the raw numbers - NOT normalized per population



df_bycounty3 = pd.DataFrame(df.groupby('county', sort=False)['newcountconfirmed'].rolling(7).mean())
df_bycounty3.set_index(keys=df.index, inplace=True)
df_bycounty3.tail(30)
df_bycounty3.columns = ['7dayrollingavg_newlyconfirmed_rawnumber']

merged3 = pd.merge(df, df_bycounty3, left_index=True, right_index=True)

df_bycounty4 = pd.DataFrame(df.groupby('county', sort=False)['newcountdeaths'].rolling(7).mean())
df_bycounty4.set_index(keys=df.index, inplace=True)

df_bycounty4.columns = ['7dayrollingavg_newdeath_rawnumber']

merged4 = pd.merge(merged3, df_bycounty4, left_index=True, right_index=True)
df = merged4.copy()
df.tail(30)
# Out:
#      county  totalcountconfirmed  totalcountdeaths  newcountconfirmed  \
# 2989   Yuba               2891.0              13.0                 40
# 2990   Yuba               2980.0              14.0                 89
# 2991   Yuba               3035.0              14.0                 55
# 2992   Yuba               3097.0              14.0                 62
# 2993   Yuba               3168.0              15.0                 71
# 2994   Yuba               3254.0              15.0                 86
# 2995   Yuba               3329.0              15.0                 75
# 2996   Yuba               3379.0              15.0                 50
# 2997   Yuba               3438.0              16.0                 59
# 2998   Yuba               3483.0              17.0                 45
# 2999   Yuba               3549.0              17.0                 66
# 3000   Yuba               3599.0              17.0                 50
# 3001   Yuba               3665.0              17.0                 66
# 3002   Yuba               3679.0              17.0                 14
# 3003   Yuba               3723.0              18.0                 44
# 3004   Yuba               3756.0              18.0                 33
# 3005   Yuba               3799.0              19.0                 43
# 3006   Yuba               3845.0              19.0                 46
# 3007   Yuba               3930.0              19.0                 85
# 3008   Yuba               3966.0              19.0                 36
# 3009   Yuba               4023.0              21.0                 57
# 3010   Yuba               4053.0              23.0                 30
# 3011   Yuba               4097.0              23.0                 44
# 3012   Yuba               4128.0              25.0                 31
# 3013   Yuba               4195.0              25.0                 67
# 3014   Yuba               4265.0              25.0                 70
# 3015   Yuba               4300.0              25.0                 35
# 3016   Yuba               4349.0              26.0                 49
# 3017   Yuba               4389.0              26.0                 40
# 3018   Yuba               4448.0              26.0                 59
#
#       newcountdeaths       date  NEVER  RARELY  SOMETIMES  FREQUENTLY  ALWAYS  \
# 2989               3 2020-12-15  0.057   0.035      0.071       0.167   0.669
# 2990               1 2020-12-16  0.057   0.035      0.071       0.167   0.669
# 2991               0 2020-12-17  0.057   0.035      0.071       0.167   0.669
# 2992               0 2020-12-18  0.057   0.035      0.071       0.167   0.669
# 2993               1 2020-12-19  0.057   0.035      0.071       0.167   0.669
# 2994               0 2020-12-20  0.057   0.035      0.071       0.167   0.669
# 2995               0 2020-12-21  0.057   0.035      0.071       0.167   0.669
# 2996               0 2020-12-22  0.057   0.035      0.071       0.167   0.669
# 2997               1 2020-12-23  0.057   0.035      0.071       0.167   0.669
# 2998               1 2020-12-24  0.057   0.035      0.071       0.167   0.669
# 2999               0 2020-12-25  0.057   0.035      0.071       0.167   0.669
# 3000               0 2020-12-26  0.057   0.035      0.071       0.167   0.669
# 3001               0 2020-12-27  0.057   0.035      0.071       0.167   0.669
# 3002               0 2020-12-28  0.057   0.035      0.071       0.167   0.669
# 3003               1 2020-12-29  0.057   0.035      0.071       0.167   0.669
# 3004               0 2020-12-30  0.057   0.035      0.071       0.167   0.669
# 3005               1 2020-12-31  0.057   0.035      0.071       0.167   0.669
# 3006               0 2021-01-01  0.057   0.035      0.071       0.167   0.669
# 3007               0 2021-01-02  0.057   0.035      0.071       0.167   0.669
# 3008               0 2021-01-03  0.057   0.035      0.071       0.167   0.669
# 3007      0.000000                      60.107940                 0.363190
# 3008      0.000000                      54.660091                 0.363190
# 3009      2.542330                      62.468675                 0.726380
# 3010      2.542330                      59.926345                 0.907975
# 3011      0.000000                      61.923890                 0.907975
# 3012      2.542330                      59.744750                 1.089570
# 3013      0.000000                      63.558245                 1.089570
# 3014      0.000000                      60.834320                 1.089570
# 3015      0.000000                      60.652725                 1.089570
# 3016      1.271165                      59.199965                 0.907975
# 3017      0.000000                      61.015915                 0.544785
# 3018      0.000000                      63.739840                 0.544785
#
#       7dayrollingavg_newlyconfirmed_rawnumber  \
# 2989                                59.142857
# 2990                                66.714286
# 2991                                61.571429
# 2992                                64.000000
# 2993                                68.000000
# 2994                                71.428571
# 2995                                68.285714
# 2996                                69.714286
# 2997                                65.428571
# 2998                                64.000000
# 2999                                64.571429
# 3000                                61.571429
# 3001                                58.714286
# 3002                                50.000000
# 3003                                49.142857
# 3004                                45.428571
# 3005                                45.142857
# 3006                                42.285714
# 3007                                47.285714
# 3008                                43.000000
# 3009                                49.142857
# 3010                                47.142857
# 3011                                48.714286
# 3012                                47.000000
# 3013                                50.000000
# 3014                                47.857143
# 3015                                47.714286
# 3016                                46.571429
# 3017                                48.000000
# 3018                                50.142857
#
#       7dayrollingavg_newdeath_rawnumber
# 2989                           0.285714
# 2990                           0.571429
# 2991                           0.571429
# 2992                           0.571429
# 2993                           0.714286
# 2994                           0.714286
# 2995                           0.714286
# 2996                           0.285714
# 2997                           0.285714
# 2998                           0.428571
# 2999                           0.428571
# 3000                           0.285714
# 3001                           0.285714
# 3002                           0.285714
# 3003                           0.428571
# 3004                           0.285714
# 3005                           0.285714
# 3006                           0.285714
# 3007                           0.285714
# 3008                           0.285714
# 3009                           0.571429
# 3010                           0.714286
# 3011                           0.714286
# 3012                           0.857143
# 3013                           0.857143
# 3014                           0.857143
# 3015                           0.857143
# 3016                           0.714286
# 3017                           0.428571
# 3018                           0.428571

# %%
# graph the raw number of confirmed cases for each county
# on same y-axis scale to show the population differences among counties 


sns.set_theme(style="darkgrid")

g = sns.FacetGrid(df, col="county", col_wrap=4, height=4, aspect=1, sharex=False, margin_titles=True, ylim=(0,5000))
g.map(sns.lineplot, "date", '7dayrollingavg_newlyconfirmed_rawnumber', label='7-Day Average')
g.map(sns.scatterplot, "date", 'newcountconfirmed', alpha=.5, color='lightskyblue', label='Daily Confirmed (raw number)')

xformatter = mdates.DateFormatter("%y/%m")

g.axes[0].xaxis.set_major_formatter(xformatter)

g.set_xticklabels(rotation=50)
g.fig.tight_layout()
g.add_legend()

# %%
# graph the raw number of confirmed deaths for each county
# on same y-axis scale to show the population differences among counties 



g = sns.FacetGrid(df, col="county", col_wrap=4, height=4, aspect=1, sharex=False, margin_titles=True, ylim=(0,100))
g.map(sns.lineplot, "date", '7dayrollingavg_newdeath_rawnumber', color='crimson', label='7-Day Average')
g.map(sns.scatterplot, "date", 'newcountdeaths', alpha=.5, color='lightpink', label='DailyDeath (raw number)')

xformatter = mdates.DateFormatter("%y/%m")

g.axes[0].xaxis.set_major_formatter(xformatter)

g.set_xticklabels(rotation=50)
g.fig.tight_layout()

g.add_legend()

# %%
df.corr()
# Out:
#                                          totalcountconfirmed  \
# totalcountconfirmed                                 1.000000
# totalcountdeaths                                    0.949822
# newcountconfirmed                                   0.866452
# newcountdeaths                                      0.749547
# NEVER                                              -0.084601
# RARELY                                             -0.127947
# SOMETIMES                                          -0.088846
# FREQUENTLY                                         -0.125150
# ALWAYS                                              0.149037
# population                                          0.691354
# confirmedper100k                                    0.342603
# newlyconfirmedper100k                               0.212407
# deathper100k                                        0.360146
# newdeath100k                                        0.102545
# 7dayrollingavg_newlyconfirmed                       0.296173
# 7dayrollingavg_newdeath                             0.197686
# 7dayrollingavg_newlyconfirmed_rawnumber             0.913069
# 7dayrollingavg_newdeath_rawnumber                   0.843518
#
#                                          totalcountdeaths  newcountconfirmed  \
# totalcountconfirmed                              0.949822           0.866452
# totalcountdeaths                                 1.000000           0.753252
# newcountconfirmed                                0.753252           1.000000
# newcountdeaths                                   0.697628           0.742399
# NEVER                                           -0.085125          -0.065983
# RARELY                                          -0.131276          -0.099680
# SOMETIMES                                       -0.092298          -0.074482
# FREQUENTLY                                      -0.128445          -0.098003
# ALWAYS                                           0.152876           0.118276
# population                                       0.798887           0.543334
# confirmedper100k                                 0.261336           0.294297
# newlyconfirmedper100k                            0.141618           0.292713
# deathper100k                                     0.342834           0.273227
# newdeath100k                                     0.082189           0.106398
# 7dayrollingavg_newlyconfirmed                    0.194444           0.341623
# 7dayrollingavg_newdeath                          0.159843           0.192645
# 7dayrollingavg_newlyconfirmed_rawnumber          0.788879           0.951804
# 7dayrollingavg_newdeath_rawnumber                0.795903           0.792793
#
#                                          newcountdeaths     NEVER    RARELY  \
# totalcountconfirmed                            0.749547 -0.084601 -0.127947
# totalcountdeaths                               0.697628 -0.085125 -0.131276
# newcountconfirmed                              0.742399 -0.065983 -0.099680
# newcountdeaths                                 1.000000 -0.064787 -0.098021
# NEVER                                         -0.064787  1.000000  0.322411
# RARELY                                        -0.098021  0.322411  1.000000
# SOMETIMES                                     -0.069152  0.208287  0.426203
# FREQUENTLY                                    -0.092419  0.153016  0.379223
# ALWAYS                                         0.113137 -0.539908 -0.701203
# population                                     0.588485 -0.157266 -0.219864
# confirmedper100k                               0.199046 -0.074161 -0.112030
# newlyconfirmedper100k                          0.151223 -0.022087 -0.034277
# deathper100k                                   0.223436 -0.161930 -0.230415
# newdeath100k                                   0.237232 -0.034672 -0.054535
# 7dayrollingavg_newlyconfirmed                  0.206539 -0.028738 -0.045432
# 7dayrollingavg_newdeath                        0.227708 -0.069161 -0.114020
# 7dayrollingavg_newlyconfirmed_rawnumber        0.766701 -0.069370 -0.104912
# 7dayrollingavg_newdeath_rawnumber              0.879053 -0.076155 -0.115733
#
#                                          SOMETIMES  FREQUENTLY    ALWAYS  \
# totalcountconfirmed                      -0.088846   -0.125150  0.149037
# totalcountdeaths                         -0.092298   -0.128445  0.152876
# newcountconfirmed                        -0.074482   -0.098003  0.118276
# newcountdeaths                           -0.069152   -0.092419  0.113137
# NEVER                                     0.208287    0.153016 -0.539908
# RARELY                                    0.426203    0.379223 -0.701203
# SOMETIMES                                 1.000000    0.570585 -0.796940
# FREQUENTLY                                0.570585    1.000000 -0.796274
# ALWAYS                                   -0.796940   -0.796274  1.000000
# population                               -0.173346   -0.198758  0.260548
# confirmedper100k                          0.041887   -0.104299  0.084494
# newlyconfirmedper100k                     0.046948   -0.022560  0.009146
# deathper100k                             -0.115553   -0.198655  0.243100
# newdeath100k                             -0.008402   -0.033531  0.043645
# 7dayrollingavg_newlyconfirmed             0.070570   -0.029000  0.008534
# 7dayrollingavg_newdeath                  -0.021870   -0.075753  0.094237
# 7dayrollingavg_newlyconfirmed_rawnumber  -0.078137   -0.103155  0.124369
# 7dayrollingavg_newdeath_rawnumber        -0.081453   -0.109794  0.133687
#
#                                          population  confirmedper100k  \
# totalcountconfirmed                        0.691354          0.342603
# totalcountdeaths                           0.798887          0.261336
# newcountconfirmed                          0.543334          0.294297
# newcountdeaths                             0.588485          0.199046
# NEVER                                     -0.157266         -0.074161
# RARELY                                    -0.219864         -0.112030
# SOMETIMES                                 -0.173346          0.041887
# FREQUENTLY                                -0.198758         -0.104299
# ALWAYS                                     0.260548          0.084494
# population                                 1.000000          0.092152
# confirmedper100k                           0.092152          1.000000
# newlyconfirmedper100k                      0.048850          0.533606
# deathper100k                               0.188796          0.781001
# newdeath100k                               0.043499          0.226726
# 7dayrollingavg_newlyconfirmed              0.066652          0.765596
# 7dayrollingavg_newdeath                    0.087356          0.461336
# 7dayrollingavg_newlyconfirmed_rawnumber    0.571910          0.311392
# 7dayrollingavg_newdeath_rawnumber          0.692118          0.222583
#
#                                          newlyconfirmedper100k  deathper100k  \
# totalcountconfirmed                                   0.212407      0.360146
# totalcountdeaths                                      0.141618      0.342834
# newcountconfirmed                                     0.292713      0.273227
# newcountdeaths                                        0.151223      0.223436
# NEVER                                                -0.022087     -0.161930
# RARELY                                               -0.034277     -0.230415
# SOMETIMES                                             0.046948     -0.115553
# FREQUENTLY                                           -0.022560     -0.198655
# ALWAYS                                                0.009146      0.243100
# population                                            0.048850      0.188796
# confirmedper100k                                      0.533606      0.781001
# newlyconfirmedper100k                                 1.000000      0.335814
# deathper100k                                          0.335814      1.000000
# newdeath100k                                          0.140034      0.237372
# 7dayrollingavg_newlyconfirmed                         0.706567      0.470466
# 7dayrollingavg_newdeath                               0.299854      0.490194
# 7dayrollingavg_newlyconfirmed_rawnumber               0.258045      0.285884
# 7dayrollingavg_newdeath_rawnumber                     0.157535      0.254509
#
#                                          newdeath100k  \
# totalcountconfirmed                          0.102545
# totalcountdeaths                             0.082189
# newcountconfirmed                            0.106398
# newcountdeaths                               0.237232
# NEVER                                       -0.034672
# RARELY                                      -0.054535
# SOMETIMES                                   -0.008402
# FREQUENTLY                                  -0.033531
# ALWAYS                                       0.043645
# population                                   0.043499
# confirmedper100k                             0.226726
# newlyconfirmedper100k                        0.140034
# deathper100k                                 0.237372
# newdeath100k                                 1.000000
# 7dayrollingavg_newlyconfirmed                0.213600
# 7dayrollingavg_newdeath                      0.490619
# 7dayrollingavg_newlyconfirmed_rawnumber      0.109955
# 7dayrollingavg_newdeath_rawnumber            0.131790
#
#                                          7dayrollingavg_newlyconfirmed  \
# totalcountconfirmed                                           0.296173
# totalcountdeaths                                              0.194444
# newcountconfirmed                                             0.341623
# newcountdeaths                                                0.206539
# NEVER                                                        -0.028738
# RARELY                                                       -0.045432
# SOMETIMES                                                     0.070570
# FREQUENTLY                                                   -0.029000
# ALWAYS                                                        0.008534
# population                                                    0.066652
# confirmedper100k                                              0.765596
# newlyconfirmedper100k                                         0.706567
# deathper100k                                                  0.470466
# newdeath100k                                                  0.213600
# 7dayrollingavg_newlyconfirmed                                 1.000000
# 7dayrollingavg_newdeath                                       0.434307
# 7dayrollingavg_newlyconfirmed_rawnumber                       0.362044
# 7dayrollingavg_newdeath_rawnumber                             0.227946
#
#                                          7dayrollingavg_newdeath  \
# totalcountconfirmed                                     0.197686
# totalcountdeaths                                        0.159843
# newcountconfirmed                                       0.192645
# newcountdeaths                                          0.227708
# NEVER                                                  -0.069161
# RARELY                                                 -0.114020
# SOMETIMES                                              -0.021870
# FREQUENTLY                                             -0.075753
# ALWAYS                                                  0.094237
# population                                              0.087356
# confirmedper100k                                        0.461336
# newlyconfirmedper100k                                   0.299854
# deathper100k                                            0.490194
# newdeath100k                                            0.490619
# 7dayrollingavg_newlyconfirmed                           0.434307
# 7dayrollingavg_newdeath                                 1.000000
# 7dayrollingavg_newlyconfirmed_rawnumber                 0.210293
# 7dayrollingavg_newdeath_rawnumber                       0.258762
#
#                                          7dayrollingavg_newlyconfirmed_rawnumber  \
# totalcountconfirmed                                                     0.913069
# totalcountdeaths                                                        0.788879
# newcountconfirmed                                                       0.951804
# newcountdeaths                                                          0.766701
# NEVER                                                                  -0.069370
# RARELY                                                                 -0.104912
# SOMETIMES                                                              -0.078137
# FREQUENTLY                                                             -0.103155
# ALWAYS                                                                  0.124369
# population                                                              0.571910
# confirmedper100k                                                        0.311392
# newlyconfirmedper100k                                                   0.258045
# deathper100k                                                            0.285884
# newdeath100k                                                            0.109955
# 7dayrollingavg_newlyconfirmed                                           0.362044
# 7dayrollingavg_newdeath                                                 0.210293
# 7dayrollingavg_newlyconfirmed_rawnumber                                 1.000000
# 7dayrollingavg_newdeath_rawnumber                                       0.851888
#
#                                          7dayrollingavg_newdeath_rawnumber
# totalcountconfirmed                                               0.843518
# totalcountdeaths                                                  0.795903
# newcountconfirmed                                                 0.792793
# newcountdeaths                                                    0.879053
# NEVER                                                            -0.076155
# RARELY                                                           -0.115733
# SOMETIMES                                                        -0.081453
# FREQUENTLY                                                       -0.109794
# ALWAYS                                                            0.133687
# population                                                        0.692118
# confirmedper100k                                                  0.222583
# newlyconfirmedper100k                                             0.157535
# deathper100k                                                      0.254509
# newdeath100k                                                      0.131790
# 7dayrollingavg_newlyconfirmed                                     0.227946
# 7dayrollingavg_newdeath                                           0.258762
# 7dayrollingavg_newlyconfirmed_rawnumber                           0.851888
# 7dayrollingavg_newdeath_rawnumber                                 1.000000

# %%
df.to_csv('Cases_Normalized_per_100k.csv', index=False)
