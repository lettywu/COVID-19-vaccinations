# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image as mpimg
import geopandas as gpd

# %%
# importing the county cases mask data
data_mask = pd.read_csv('/Users/rahulparab/dsi/08-week/COVID-19-vaccinations/clean_data/cases_with_mask_use.csv')

# %%
# importing the hospital by county data
data_hosp = pd.read_csv('/Users/rahulparab/dsi/08-week/COVID-19-vaccinations/clean_data/hospitals_by_county.csv')

# %%
data_mask.head()
# Out:
#         county  totalcountconfirmed  totalcountdeaths  newcountconfirmed  \
# 0  Santa Clara                151.0               6.0                151
# 1  Santa Clara                183.0               8.0                 32
# 2  Santa Clara                246.0               8.0                 63
# 3  Santa Clara                269.0              10.0                 23
# 4  Santa Clara                284.0              13.0                 15
#
#    newcountdeaths        date  NEVER  RARELY  SOMETIMES  FREQUENTLY  ALWAYS  \
# 0               6  2020-03-18  0.015   0.014       0.04       0.168   0.764
# 1               2  2020-03-19  0.015   0.014       0.04       0.168   0.764
# 2               0  2020-03-20  0.015   0.014       0.04       0.168   0.764
# 3               2  2020-03-21  0.015   0.014       0.04       0.168   0.764
# 4               3  2020-03-22  0.015   0.014       0.04       0.168   0.764
#
#    population
# 0     1927852
# 1     1927852
# 2     1927852
# 3     1927852
# 4     1927852

# %%
data_county_pop = data_mask[['county', 'date' , 'population']]

# %%
# merge the hospital county and county population data together.

# %%
data_hosp
# Out:
#                 county todays_date  hospitalized_covid_confirmed_patients  \
# 0                Kings  2020-03-29                                    2.0
# 1                 Yolo  2020-03-29                                    2.0
# 2            San Diego  2020-03-29                                  121.0
# 3                Modoc  2020-03-29                                    0.0
# 4                 Mono  2020-03-29                                    0.0
# ...                ...         ...                                    ...
# 16288     Contra Costa  2021-01-13                                  250.0
# 16289           Placer  2021-01-13                                  165.0
# 16290  San Luis Obispo  2021-01-13                                   57.0
# 16291             Yuba  2021-01-13                                   53.0
# 16292           Madera  2021-01-13                                   52.0
#
#        hospitalized_suspected_covid_patients  hospitalized_covid_patients  \
# 0                                        5.0                          7.0
# 1                                        3.0                          5.0
# 2                                      211.0                        332.0
# 3                                        0.0                          0.0
# 4                                        1.0                          1.0
# ...                                      ...                          ...
# 16288                                   10.0                        260.0
# 16289                                   12.0                        177.0
# 16290                                    2.0                         59.0
# 16291                                    0.0                         53.0
# 16292                                    9.0                         61.0
#
#        all_hospital_beds  icu_covid_confirmed_patients  \
# 0                  292.0                           1.0
# 1                  251.0                           1.0
# 2                 4459.0                          77.0
# 3                   11.0                           0.0
# 4                  292.0                           0.0
# ...                  ...                           ...
# 16288             1600.0                          61.0
# 16289              754.0                          28.0
# 16290              460.0                           7.0
# 16291              261.0                          15.0
# 16292              279.0                          11.0
#
#        icu_suspected_covid_patients  icu_available_beds
# 0                               0.0                 2.0
# 1                               1.0                 0.0
# 2                              39.0               205.0
# 3                               0.0                 0.0
# 4                               0.0                 2.0
# ...                             ...                 ...
# 16288                           1.0                40.0
# 16289                           2.0                 8.0
# 16290                           0.0                16.0
# 16291                           0.0                 0.0
# 16292                           0.0                 3.0
#
# [16293 rows x 9 columns]

# %%
# lets rename column name for todays_date

data_hosp.rename(columns = {'todays_date':'date'},inplace = True)

# %%
data_hosp
# Out:
#                 county        date  hospitalized_covid_confirmed_patients  \
# 0                Kings  2020-03-29                                    2.0
# 1                 Yolo  2020-03-29                                    2.0
# 2            San Diego  2020-03-29                                  121.0
# 3                Modoc  2020-03-29                                    0.0
# 4                 Mono  2020-03-29                                    0.0
# ...                ...         ...                                    ...
# 16288     Contra Costa  2021-01-13                                  250.0
# 16289           Placer  2021-01-13                                  165.0
# 16290  San Luis Obispo  2021-01-13                                   57.0
# 16291             Yuba  2021-01-13                                   53.0
# 16292           Madera  2021-01-13                                   52.0
#
#        hospitalized_suspected_covid_patients  hospitalized_covid_patients  \
# 0                                        5.0                          7.0
# 1                                        3.0                          5.0
# 2                                      211.0                        332.0
# 3                                        0.0                          0.0
# 4                                        1.0                          1.0
# ...                                      ...                          ...
# 16288                                   10.0                        260.0
# 16289                                   12.0                        177.0
# 16290                                    2.0                         59.0
# 16291                                    0.0                         53.0
# 16292                                    9.0                         61.0
#
#        all_hospital_beds  icu_covid_confirmed_patients  \
# 0                  292.0                           1.0
# 1                  251.0                           1.0
# 2                 4459.0                          77.0
# 3                   11.0                           0.0
# 4                  292.0                           0.0
# ...                  ...                           ...
# 16288             1600.0                          61.0
# 16289              754.0                          28.0
# 16290              460.0                           7.0
# 16291              261.0                          15.0
# 16292              279.0                          11.0
#
#        icu_suspected_covid_patients  icu_available_beds
# 0                               0.0                 2.0
# 1                               1.0                 0.0
# 2                              39.0               205.0
# 3                               0.0                 0.0
# 4                               0.0                 2.0
# ...                             ...                 ...
# 16288                           1.0                40.0
# 16289                           2.0                 8.0
# 16290                           0.0                16.0
# 16291                           0.0                 0.0
# 16292                           0.0                 3.0
#
# [16293 rows x 9 columns]

# %%
# Merge DataFrames
df= pd.merge(data_hosp, data_county_pop , on = [ 'county' , 'date'], how = 'left')

# %%
df.isna().sum()
# Out:
# county                                   0
# date                                     0
# hospitalized_covid_confirmed_patients    0
# hospitalized_suspected_covid_patients    0
# hospitalized_covid_patients              0
# all_hospital_beds                        0
# icu_covid_confirmed_patients             0
# icu_suspected_covid_patients             0
# icu_available_beds                       0
# population                               6
# dtype: int64

# %%
df.fillna('0', inplace = True)

# %%
df
# Out:
#                 county        date  hospitalized_covid_confirmed_patients  \
# 0                Kings  2020-03-29                                    2.0
# 1                 Yolo  2020-03-29                                    2.0
# 2            San Diego  2020-03-29                                  121.0
# 3                Modoc  2020-03-29                                    0.0
# 4                 Mono  2020-03-29                                    0.0
# ...                ...         ...                                    ...
# 16288     Contra Costa  2021-01-13                                  250.0
# 16289           Placer  2021-01-13                                  165.0
# 16290  San Luis Obispo  2021-01-13                                   57.0
# 16291             Yuba  2021-01-13                                   53.0
# 16292           Madera  2021-01-13                                   52.0
#
#        hospitalized_suspected_covid_patients  hospitalized_covid_patients  \
# 0                                        5.0                          7.0
# 1                                        3.0                          5.0
# 2                                      211.0                        332.0
# 3                                        0.0                          0.0
# 4                                        1.0                          1.0
# ...                                      ...                          ...
# 16288                                   10.0                        260.0
# 16289                                   12.0                        177.0
# 16290                                    2.0                         59.0
# 16291                                    0.0                         53.0
# 16292                                    9.0                         61.0
#
#        all_hospital_beds  icu_covid_confirmed_patients  \
# 0                  292.0                           1.0
# 1                  251.0                           1.0
# 2                 4459.0                          77.0
# 3                   11.0                           0.0
# 4                  292.0                           0.0
# ...                  ...                           ...
# 16288             1600.0                          61.0
# 16289              754.0                          28.0
# 16290              460.0                           7.0
# 16291              261.0                          15.0
# 16292              279.0                          11.0
#
#        icu_suspected_covid_patients  icu_available_beds   population
# 0                               0.0                 2.0       152940
# 1                               1.0                 0.0       220500
# 2                              39.0               205.0  3.33833e+06
# 3                               0.0                 0.0            0
# 4                               0.0                 2.0        14444
# ...                             ...                 ...          ...
# 16288                           1.0                40.0  1.15353e+06
# 16289                           2.0                 8.0       398329
# 16290                           0.0                16.0       283111
# 16291                           0.0                 0.0        78668
# 16292                           0.0                 3.0       157327
#
# [16293 rows x 10 columns]

# %%
df_raw = df[['county','date','hospitalized_covid_patients','population']]

# %%
df_raw
# Out:
#                 county        date  hospitalized_covid_patients   population
# 0                Kings  2020-03-29                          7.0       152940
# 1                 Yolo  2020-03-29                          5.0       220500
# 2            San Diego  2020-03-29                        332.0  3.33833e+06
# 3                Modoc  2020-03-29                          0.0            0
# 4                 Mono  2020-03-29                          1.0        14444
# ...                ...         ...                          ...          ...
# 16288     Contra Costa  2021-01-13                        260.0  1.15353e+06
# 16289           Placer  2021-01-13                        177.0       398329
# 16290  San Luis Obispo  2021-01-13                         59.0       283111
# 16291             Yuba  2021-01-13                         53.0        78668
# 16292           Madera  2021-01-13                         61.0       157327
#
# [16293 rows x 4 columns]

# %%
df_raw.groupby(by = ['county','date'])['hospitalized_covid_patients'].sum()
# Out:
# county   date
# Alameda  2020-03-29    127.0
#          2020-03-30    148.0
#          2020-03-31    150.0
#          2020-04-01    128.0
#          2020-04-02    133.0
#                        ...
# Yuba     2021-01-09     56.0
#          2021-01-10     56.0
#          2021-01-11     54.0
#          2021-01-12     55.0
#          2021-01-13     53.0
# Name: hospitalized_covid_patients, Length: 16293, dtype: float64

# %% [markdown]
# #### Using Geopandas for plotting

# %%
df_raw.to_csv('/Users/rahulparab/dsi/08-week/COVID-19-vaccinations/clean_data/hospitals_by_county_with_pop.csv', index=False)

# %%
# set the filepath and load in a shapefile
map_df = gpd.read_file('/Users/rahulparab/dsi/08-week/COVID-19-vaccinations/data/CA_Counties/CA_Counties_TIGER2016.shp')
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS  GEOID           NAME              NAMELSAD LSAD  \
# 0      06      091  00277310  06091         Sierra         Sierra County   06
# 1      06      067  00277298  06067     Sacramento     Sacramento County   06
# 2      06      083  00277306  06083  Santa Barbara  Santa Barbara County   06
# 3      06      009  01675885  06009      Calaveras      Calaveras County   06
# 4      06      111  00277320  06111        Ventura        Ventura County   06
#
#   CLASSFP  MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND      AWATER  \
# 0      H1  G4020  None   None     None        A  2468694587    23299110
# 1      H1  G4020   472  40900     None        A  2499183617    76073827
# 2      H1  G4020  None  42200     None        A  7084000598  2729814515
# 3      H1  G4020  None   None     None        A  2641820834    43806026
# 4      H1  G4020   348  37100     None        A  4773390489   945942791
#
#       INTPTLAT      INTPTLON  \
# 0  +39.5769252  -120.5219926
# 1  +38.4500114  -121.3404409
# 2  +34.5370572  -120.0399729
# 3  +38.1838996  -120.5614415
# 4  +34.3587415  -119.1331432
#
#                                             geometry
# 0  POLYGON ((-13431319.751 4821511.426, -13431312...
# 1  POLYGON ((-13490651.476 4680831.603, -13490511...
# 2  MULTIPOLYGON (((-13423116.772 4042044.149, -13...
# 3  POLYGON ((-13428575.483 4627725.228, -13428534...
# 4  MULTIPOLYGON (((-13317853.594 3931602.414, -13...

# %%
map_df.plot();

# %%
df_raw.columns
# Out:
# Index(['county', 'date', 'hospitalized_covid_patients', 'population'], dtype='object')

# %%
# join the geodataframe with the cleaned up csv dataframe
merged = map_df.set_index('NAME').join(df_raw.set_index('county'))
merged.head()
# Out:
#         STATEFP COUNTYFP  COUNTYNS  GEOID        NAMELSAD LSAD CLASSFP  MTFCC  \
# Alameda      06      001  01675839  06001  Alameda County   06      H1  G4020
# Alameda      06      001  01675839  06001  Alameda County   06      H1  G4020
# Alameda      06      001  01675839  06001  Alameda County   06      H1  G4020
# Alameda      06      001  01675839  06001  Alameda County   06      H1  G4020
# Alameda      06      001  01675839  06001  Alameda County   06      H1  G4020
#
#         CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND     AWATER     INTPTLAT  \
# Alameda   488  41860    36084        A  1914242789  212979931  +37.6471385
# Alameda   488  41860    36084        A  1914242789  212979931  +37.6471385
# Alameda   488  41860    36084        A  1914242789  212979931  +37.6471385
# Alameda   488  41860    36084        A  1914242789  212979931  +37.6471385
# Alameda   488  41860    36084        A  1914242789  212979931  +37.6471385
#
#              INTPTLON                                           geometry  \
# Alameda  -121.9124880  POLYGON ((-13612246.763 4538150.085, -13612346...
# Alameda  -121.9124880  POLYGON ((-13612246.763 4538150.085, -13612346...
# Alameda  -121.9124880  POLYGON ((-13612246.763 4538150.085, -13612346...
# Alameda  -121.9124880  POLYGON ((-13612246.763 4538150.085, -13612346...
# Alameda  -121.9124880  POLYGON ((-13612246.763 4538150.085, -13612346...
#
#                date  hospitalized_covid_patients   population
# Alameda  2020-03-29                        127.0  1.67133e+06
# Alameda  2020-03-30                        148.0  1.67133e+06
# Alameda  2020-03-31                        150.0  1.67133e+06
# Alameda  2020-04-01                        128.0  1.67133e+06
# Alameda  2020-04-02                        133.0  1.67133e+06

# %%
merged['percent_covid_pop'] = (merged['hospitalized_covid_patients'] )*100 /  (pd.to_numeric(merged['population'], downcast="float"))

# %%
sns.boxplot( y=merged["hospitalized_covid_patients"] )
# Out:
# <AxesSubplot:ylabel='hospitalized_covid_patients'>

# %%
# set a variable that will call whatever column we want to visualise on the map
variable = 'hospitalized_covid_patients'

# set the range for the choropleth
vmin, vmax = 1 , 1.5 

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# create map
merged.plot(column=variable, cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8')

# Now we can customise and add annotations

# remove the axis
ax.axis('off')

# add a title
ax.set_title('Covid density by population', \
              fontdict={'fontsize': '25',
                        'fontweight' : '3'})

# create an annotation for the  data source
ax.annotate('CA Covid number 2020',
           xy=(0.1, 0.1), xycoords='figure fraction',
           horizontalalignment='left', verticalalignment='top',
           fontsize=10, color='#555555')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
cbar = fig.colorbar(sm)

# this will save the figure as a high-res png. you can also save as svg
fig.savefig('testmap.png', dpi=500)
